# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Embedding, SimpleRNN
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

# Load the dataset
data = pd.read_csv('emotion_dataset_2.csv')

# Split the data into text and labels
text = data['Clean_Text'].astype(str).values
labels = data['Emotion'].values

# Tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)
vocab_size = len(tokenizer.word_index) + 1
sequences = tokenizer.texts_to_sequences(text)
max_sequence_length = max([len(seq) for seq in sequences])
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)

label_mapping = {'neutral':0, 'joy':1, 'sadness':2, 'fear':3, 'surprise':4, 'anger':5, 'shame':6,
       'disgust':7}
labels = np.array([label_mapping[label] for label in labels])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# Define the RNN model
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_sequence_length))
model.add(SimpleRNN(128))
model.add(Dense(8, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Make predictions
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')


print("Accuracy: {:.2f}".format(accuracy))
print("Precision: {:.2f}".format(precision))
print("Recall: {:.2f}".format(recall))
print("F1-Score: {:.2f}".format(f1))
# Out:
# Epoch 1/10
# 870/870 [==============================] - 40s 45ms/step - loss: 1.4153 - accuracy: 0.4783 - val_loss: 1.1767 - val_accuracy: 0.5892
# Epoch 2/10
# 870/870 [==============================] - 35s 40ms/step - loss: 0.6151 - accuracy: 0.7989 - val_loss: 1.2681 - val_accuracy: 0.5876
# Epoch 3/10
# 870/870 [==============================] - 34s 39ms/step - loss: 0.2062 - accuracy: 0.9374 - val_loss: 1.5924 - val_accuracy: 0.5774
# Epoch 4/10
# 870/870 [==============================] - 36s 42ms/step - loss: 0.1391 - accuracy: 0.9574 - val_loss: 1.9527 - val_accuracy: 0.5600
# Epoch 5/10
# 870/870 [==============================] - 35s 40ms/step - loss: 0.0882 - accuracy: 0.9738 - val_loss: 2.1742 - val_accuracy: 0.5482
# Epoch 6/10
# 870/870 [==============================] - 36s 41ms/step - loss: 0.1040 - accuracy: 0.9678 - val_loss: 2.3056 - val_accuracy: 0.5540
# Epoch 7/10
# 870/870 [==============================] - 34s 40ms/step - loss: 0.0615 - accuracy: 0.9815 - val_loss: 2.5155 - val_accuracy: 0.5495
# Epoch 8/10
# 870/870 [==============================] - 35s 41ms/step - loss: 0.0557 - accuracy: 0.9831 - val_loss: 2.6012 - val_accuracy: 0.5494
# Epoch 9/10
# 870/870 [==============================] - 35s 40ms/step - loss: 0.0556 - accuracy: 0.9826 - val_loss: 2.7495 - val_accuracy: 0.5407
# Epoch 10/10
# 870/870 [==============================] - 34s 40ms/step - loss: 0.0734 - accuracy: 0.9771 - val_loss: 2.8098 - val_accuracy: 0.5348
# 218/218 [==============================] - 1s 6ms/step
# Accuracy: 0.53
# Precision: 0.53
# Recall: 0.53
# F1-Score: 0.53
